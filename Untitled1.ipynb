# %%
# %load read_cifar10_direct.py


# In[30]:


from __future__ import print_function
import traceback
import sys
import glob
import os
import tensorflow as tf
import matplotlib.image as mpimg # mpimg 用于读取图片
import numpy

directory= '/home/dp/down/cifar10/cifar-10-unpack/classify' #目标文件夹
classlist=list()

def read_cifar10():
         
    images, labels = [], []
    # 读取训练集
    train_dir=os.path.join(directory,'train')
    train_classlist=os.listdir(train_dir)

    filenames=list()
    labels=list()
    for classes in train_classlist:
        class_path=os.path.join(train_dir,classes)
        filelist=os.listdir(class_path)
        print('classname='+classes)
        for file in filelist:
            filefullName=os.path.join(class_path,file)
            #image_string = tf.read_file(filefullName)
            #image_decoded = tf.image.decode_png(image_string, channels=3)
            #image_resized = tf.image.resize_images(image_decoded, [32, 32])
            image_decoded = mpimg.imread(filefullName) 
            # 此时已经是一个 np.array 了，可以对它进行任意处理
            image_decoded.reshape(32, 32, 3)
            image_decoded = image_decoded.astype(float)
            images.append(image_decoded)
            labels.append(train_classlist.index(classes))


    images = numpy.array(images, dtype='float')
    labels = numpy.array(labels, dtype='int')
    print(images,labels)
    #self.train_images, self.train_labels = images, labels
    
# 函数的功能时将filename对应的图片文件读进来，并缩放到统一的大小
def _parse_function(filename, label):
    image_string = tf.read_file(filename)
    image_decoded = tf.image.decode_png(image_string, channels=3)
    image_resized = tf.image.resize_images(image_decoded, [28, 28])
   
    #one_hot = tf.one_hot(label, 10) #one_hot = tf.one_hot(label, NUM_CLASSES)
    return image_resized, label
    #return image_resized, one_hot
read_cifar10()
# Out:
# classname=truck
# classname=dog
# classname=frog
# classname=horse
# classname=ship
# classname=airplane
# classname=deer
# classname=bird
# classname=cat
# classname=automobile
# [[[[ 0.75294119  0.84705883  0.94509804]
#    [ 0.75294119  0.84705883  0.94509804]
#    [ 0.75294119  0.8509804   0.94901961]
#    ...,
#    [ 0.81960785  0.90980393  0.97254902]
#    [ 0.82745099  0.9137255   0.97647059]
#    [ 0.82745099  0.90196079  0.96862745]]
#
#   [[ 0.75294119  0.84705883  0.93725491]
#    [ 0.75686276  0.85490197  0.94509804]
#    [ 0.75686276  0.8509804   0.94117647]
#    ...,
#    [ 0.80392158  0.90196079  0.94901961]
#    [ 0.79215688  0.89411765  0.94901961]
#    [ 0.7764706   0.86274511  0.94117647]]
#
#   [[ 0.78039217  0.87843138  0.95294118]
#    [ 0.78431374  0.88235295  0.96078432]
#    [ 0.78039217  0.88235295  0.95686275]
#    ...,
#    [ 0.81176472  0.90588236  0.96078432]
#    [ 0.79607844  0.90196079  0.96078432]
#    [ 0.7764706   0.87450981  0.94901961]]
#
#   ...,
#   [[ 0.44313726  0.40000001  0.32941177]
#    [ 0.44705883  0.40392157  0.33333334]
#    [ 0.44705883  0.40392157  0.33333334]
#    ...,
#    [ 0.39607844  0.33725491  0.28627452]
#    [ 0.40000001  0.34509805  0.29019609]
#    [ 0.40000001  0.34901962  0.29019609]]
#
#   [[ 0.45490196  0.41176471  0.34117648]
#    [ 0.4627451   0.41960785  0.34901962]
#    [ 0.46666667  0.42352942  0.35294119]
#    ...,
#    [ 0.49803922  0.42745098  0.35294119]
#    [ 0.49019608  0.42352942  0.35294119]
#    [ 0.47843137  0.41960785  0.35294119]]
#
